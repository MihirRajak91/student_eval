# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.notnull().sum()
# Out:
# gender                         1000
# race/ethnicity                 1000
# parental level of education    1000
# lunch                          1000
# test preparation course        1000
# math score                     1000
# reading score                  1000
# writing score                  1000
# dtype: int64

# %%
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
bins = [0, 20, 40, 60, 80, 100]
labels = ['0-20', '21-40', '41-60', '61-80', '81-100']
df['math_score_bins'] = pd.cut(df['math score'], bins=bins, labels=labels, right=False)
sns.countplot(x='math_score_bins', data=df, order=labels)
plt.title('Count of Students by Math Score Range')
plt.xlabel('Math Score Range')
plt.ylabel('Count')
plt.show()

# %%
df['Math_PassStatus'] = np.where(df['math score'] > 32 , 'P', 'F')
df.Math_PassStatus.value_counts()
# Out:
# Math_PassStatus
# P    981
# F     19
# Name: count, dtype: int64

# %%
sns.countplot(x='Math_PassStatus', data=df, palette='pastel')
plt.title('Math Pass/Fail Counts')
plt.xlabel('Math Pass/Fail')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_41844\498295911.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Math_PassStatus', data=df, palette='pastel')

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='parental level of education', hue='Math_PassStatus', data=df, palette='Set2')
plt.title('Parental Education vs. Math Pass/Fail')
plt.xlabel('Parental Level of Education')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability
plt.legend(title='Math Pass/Fail', loc='upper right')
plt.show()

# %%
bins = [0, 20, 40, 60, 80, 100]
labels = ['0-20', '21-40', '41-60', '61-80', '81-100']
df['reading_score_bins'] = pd.cut(df['reading score'], bins=bins, labels=labels, right=False)
sns.countplot(x='reading_score_bins', data=df, order=labels)
plt.title('Count of Students by Reading Score Range')
plt.xlabel('Reading Score Range')
plt.ylabel('Count')
plt.show()

# %%
df['reading_PassStatus'] = np.where(df['reading score'] > 32 , 'P', 'F')
df.reading_PassStatus.value_counts()
# Out:
# reading_PassStatus
# P    989
# F     11
# Name: count, dtype: int64

# %%
sns.countplot(x='reading_PassStatus', data=df, palette='pastel')
plt.title('Reading Pass/Fail Counts')
plt.xlabel('Reading Pass/Fail')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_41844\2123255472.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='reading_PassStatus', data=df, palette='pastel')

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='parental level of education', hue='reading_PassStatus', data=df, palette='Set2')
plt.title('Parental Education vs. Reading Pass/Fail')
plt.xlabel('Parental Level of Education')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability
plt.legend(title='Reading Pass/Fail', loc='upper right')
plt.show()

# %%
bins = [0, 20, 40, 60, 80, 100]
labels = ['0-20', '21-40', '41-60', '61-80', '81-100']
df['writing_score_bins'] = pd.cut(df['writing score'], bins=bins, labels=labels, right=False)
sns.countplot(x='writing_score_bins', data=df, order=labels)
plt.title('Count of Students by writing Score Range')
plt.xlabel('writing Score Range')
plt.ylabel('Count')
plt.show()

# %%
df['writing_PassStatus'] = np.where(df['writing score'] > 32 , 'P', 'F')
df.writing_PassStatus.value_counts()
# Out:
# writing_PassStatus
# P    988
# F     12
# Name: count, dtype: int64

# %%
sns.countplot(x='writing_PassStatus', data=df, palette='pastel')
plt.title('writing Pass/Fail Counts')
plt.xlabel('writing Pass/Fail')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_41844\2283300858.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='writing_PassStatus', data=df, palette='pastel')

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='parental level of education', hue='writing_PassStatus', data=df, palette='Set2')
plt.title('Parental Education vs. writing Pass/Fail')
plt.xlabel('Parental Level of Education')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability
plt.legend(title='writing Pass/Fail', loc='upper right')
plt.show()

# %%
df['overall_passstatus'] = df.apply(lambda x : 'F' if x['Math_PassStatus'] == 'F' or x['reading_PassStatus'] == 'F' or x['writing_PassStatus'] =='F' else 'P', axis =1)

# %%
df.overall_passstatus.value_counts()
# Out:
# overall_passstatus
# P    978
# F     22
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='parental level of education', hue='overall_passstatus', data=df, palette='Set2')
plt.title('Parental Education vs. overall Pass/Fail')
plt.xlabel('Parental Level of Education')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability
plt.legend(title='overall Pass/Fail', loc='upper right')
plt.show()

# %%
df['Total_Marks'] = df['math score']+df['reading score']+df['writing score']
df['Percentage'] = df['Total_Marks']/3

# %%
df['Percentage']
# Out:
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333
#          ...
# 995    94.000000
# 996    57.333333
# 997    65.000000
# 998    74.333333
# 999    83.000000
# Name: Percentage, Length: 1000, dtype: float64

# %%
bins = [0, 20, 40, 60, 80, 100]
labels = ['0-20', '21-40', '41-60', '61-80', '81-100']
df['Percentage_score_bins'] = pd.cut(df['Percentage'], bins=bins, labels=labels, right=False)
sns.countplot(x='writing_score_bins', data=df, order=labels)
plt.title('Count of Students by Percentage Range')
plt.xlabel('Percentage Range')
plt.ylabel('Count')
plt.show()

# %%
def GetGrade(Percentage, OverAll_PassStatus):
    if ( OverAll_PassStatus == 'F'):
        return 'F'    
    if ( Percentage >= 80 ):
        return 'A'
    if ( Percentage >= 70):
        return 'B'
    if ( Percentage >= 60):
        return 'C'
    if ( Percentage >= 50):
        return 'D'
    if ( Percentage >= 40):
        return 'E'
    else: 
        return 'F'

df['Grade'] = df.apply(lambda x : GetGrade(x['Percentage'], x['overall_passstatus']), axis=1)

df.Grade.value_counts()
# Out:
# Grade
# B    261
# C    256
# A    198
# D    182
# E     72
# F     31
# Name: count, dtype: int64

# %%
sns.countplot(x="Grade", data = df, order=['A','B','C','D','E','F'],  palette="muted")
plt.show()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_41844\923253345.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Grade", data = df, order=['A','B','C','D','E','F'],  palette="muted")

# %%
p = sns.countplot(x='parental level of education', data = df, hue='Grade', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...
